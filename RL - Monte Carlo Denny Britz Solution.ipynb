# %%
# %matplotlib inline

import gym
import matplotlib
import numpy as np
import sys

from collections import defaultdict

if "../" not in sys.path:
  sys.path.append("../") 
from blackjack import BlackjackEnv
import plotting

matplotlib.style.use('ggplot')

# %%
env = BlackjackEnv()

# %%
def mc_prediction(policy, env, num_episodes, discount_factor=1.0):
    """
    Monte Carlo prediction algorithm. Calculates the value function
    for a given policy using sampling.
    
    Args:
        policy: A function that maps an observation to action probabilities.
        env: OpenAI gym environment.
        num_episodes: Number of episodes to sample.
        discount_factor: Gamma discount factor.
    
    Returns:
        A dictionary that maps from state -> value.
        The state is a tuple and the value is a float.
    """

    # Keeps track of sum and count of returns for each state
    # to calculate an average. We could use an array to save all
    # returns (like in the book) but that's memory inefficient.
    returns_sum = defaultdict(float)
    returns_count = defaultdict(float)
    
    # The final value function
    V = defaultdict(float)
    
    for i_episode in range(1, num_episodes + 1):
        # Print out which episode we're on, useful for debugging.
        if i_episode % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()

        # Generate an episode.
        # An episode is an array of (state, action, reward) tuples
        episode = []
        state = env.reset()
        print("initial state : ",state)
        for t in range(100):
            action = policy(state)
            next_state, reward, done, _ = env.step(action)
            episode.append((state, action, reward))
            print("episode : ", episode)
            if done:
                break
            state = next_state
            print("next state : ",state)

        # Find all states the we've visited in this episode
        # We convert each state to a tuple so that we can use it as a dict key
        states_in_episode = set([tuple(x[0]) for x in episode])
        for state in states_in_episode:
            # Find the first occurance of the state in the episode
            print("state in episode : ", state)
            print("episode check : ", episode)
            first_occurence_idx = next(i for i,x in enumerate(episode) if x[0] == state)
            # Sum up all rewards since the first occurance
            G = sum([x[2]*(discount_factor**i) for i,x in enumerate(episode[first_occurence_idx:])])
            # Calculate average return for this state over all sampled episodes
            returns_sum[state] += G
            returns_count[state] += 1.0
            V[state] = returns_sum[state] / returns_count[state]

    return V

# %%
def sample_policy(observation):
    """
    A policy that sticks if the player score is >= 20 and hits otherwise.
    """
    score, dealer_score, usable_ace = observation
    return 0 if score >= 20 else 1

# %%
v = mc_prediction(sample_policy, env, num_episodes=10)
# Out:
# initial state :  (8, 2, False)
# episode :  [((8, 2, False), 1, 0)]
# next state :  (15, 2, False)
# episode :  [((8, 2, False), 1, 0), ((15, 2, False), 1, 0)]
# next state :  (18, 2, False)
# episode :  [((8, 2, False), 1, 0), ((15, 2, False), 1, 0), ((18, 2, False), 1, -1)]
# state in episode :  (8, 2, False)
# episode check :  [((8, 2, False), 1, 0), ((15, 2, False), 1, 0), ((18, 2, False), 1, -1)]
# state in episode :  (15, 2, False)
# episode check :  [((8, 2, False), 1, 0), ((15, 2, False), 1, 0), ((18, 2, False), 1, -1)]
# state in episode :  (18, 2, False)
# episode check :  [((8, 2, False), 1, 0), ((15, 2, False), 1, 0), ((18, 2, False), 1, -1)]
# initial state :  (16, 3, False)
# episode :  [((16, 3, False), 1, -1)]
# state in episode :  (16, 3, False)
# episode check :  [((16, 3, False), 1, -1)]
# initial state :  (12, 3, False)
# episode :  [((12, 3, False), 1, 0)]
# next state :  (20, 3, False)
# episode :  [((12, 3, False), 1, 0), ((20, 3, False), 0, 1.0)]
# state in episode :  (12, 3, False)
# episode check :  [((12, 3, False), 1, 0), ((20, 3, False), 0, 1.0)]
# state in episode :  (20, 3, False)
# episode check :  [((12, 3, False), 1, 0), ((20, 3, False), 0, 1.0)]
# initial state :  (19, 10, False)
# episode :  [((19, 10, False), 1, -1)]
# state in episode :  (19, 10, False)
# episode check :  [((19, 10, False), 1, -1)]
# initial state :  (10, 4, False)
# episode :  [((10, 4, False), 1, 0)]
# next state :  (12, 4, False)
# episode :  [((10, 4, False), 1, 0), ((12, 4, False), 1, 0)]
# next state :  (16, 4, False)
# episode :  [((10, 4, False), 1, 0), ((12, 4, False), 1, 0), ((16, 4, False), 1, 0)]
# next state :  (18, 4, False)
# episode :  [((10, 4, False), 1, 0), ((12, 4, False), 1, 0), ((16, 4, False), 1, 0), ((18, 4, False), 1, -1)]
# state in episode :  (18, 4, False)
# episode check :  [((10, 4, False), 1, 0), ((12, 4, False), 1, 0), ((16, 4, False), 1, 0), ((18, 4, False), 1, -1)]
# state in episode :  (10, 4, False)
# episode check :  [((10, 4, False), 1, 0), ((12, 4, False), 1, 0), ((16, 4, False), 1, 0), ((18, 4, False), 1, -1)]
# state in episode :  (12, 4, False)
# episode check :  [((10, 4, False), 1, 0), ((12, 4, False), 1, 0), ((16, 4, False), 1, 0), ((18, 4, False), 1, -1)]
# state in episode :  (16, 4, False)
# episode check :  [((10, 4, False), 1, 0), ((12, 4, False), 1, 0), ((16, 4, False), 1, 0), ((18, 4, False), 1, -1)]
# initial state :  (21, 8, True)
# episode :  [((21, 8, True), 0, 1.0)]
# state in episode :  (21, 8, True)
# episode check :  [((21, 8, True), 0, 1.0)]
# initial state :  (20, 10, False)
# episode :  [((20, 10, False), 0, 1.0)]
# state in episode :  (20, 10, False)
# episode check :  [((20, 10, False), 0, 1.0)]
# initial state :  (10, 10, False)
# episode :  [((10, 10, False), 1, 0)]
# next state :  (13, 10, False)
# episode :  [((10, 10, False), 1, 0), ((13, 10, False), 1, 0)]
# next state :  (18, 10, False)
# episode :  [((10, 10, False), 1, 0), ((13, 10, False), 1, 0), ((18, 10, False), 1, -1)]
# state in episode :  (18, 10, False)
# episode check :  [((10, 10, False), 1, 0), ((13, 10, False), 1, 0), ((18, 10, False), 1, -1)]
# state in episode :  (13, 10, False)
# episode check :  [((10, 10, False), 1, 0), ((13, 10, False), 1, 0), ((18, 10, False), 1, -1)]
# state in episode :  (10, 10, False)
# episode check :  [((10, 10, False), 1, 0), ((13, 10, False), 1, 0), ((18, 10, False), 1, -1)]
# initial state :  (13, 9, False)
# episode :  [((13, 9, False), 1, 0)]
# next state :  (17, 9, False)
# episode :  [((13, 9, False), 1, 0), ((17, 9, False), 1, -1)]
# state in episode :  (17, 9, False)
# episode check :  [((13, 9, False), 1, 0), ((17, 9, False), 1, -1)]
# state in episode :  (13, 9, False)
# episode check :  [((13, 9, False), 1, 0), ((17, 9, False), 1, -1)]
# initial state :  (20, 3, True)
# episode :  [((20, 3, True), 0, 0.0)]
# state in episode :  (20, 3, True)
# episode check :  [((20, 3, True), 0, 0.0)]

# %%
V_10k = mc_prediction(sample_policy, env, num_episodes=10000)
plotting.plot_value_function(V_10k, title="10,000 Steps")
# Out:
# Episode 10000/10000.
